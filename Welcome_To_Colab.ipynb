# %% [markdown]
# <a href="https://colab.research.google.com/github/Ash200607/ash/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

from ultralytics import YOLO
from google.colab import files
import matplotlib.pyplot as plt
from PIL import Image

model = YOLO('yolov8n.pt') #Nano pretrained model

result=model("/content/aaa.jpeg",conf=0.6)

#Save detected image
result[0].save("output.jpg")

#Display output
img=Image.open("output.jpg")
plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.0 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
#
# image 1/1 /content/aaa.jpeg: 384x640 7 persons, 2 cars, 1 traffic light, 267.3ms
# Speed: 11.8ms preprocess, 267.3ms inference, 34.2ms postprocess per image at shape (1, 3, 384, 640)
